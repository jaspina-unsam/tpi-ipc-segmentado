# %%
import pandas as pd

# %%
engh = pd.read_csv("data/engho2018_gastos.txt", sep="|")

# %%
engh.head()
# Out:
#      id  provincia  miembro  pondera  region subregion  articulo subclase  \
# 0  8558         14        0      749       2        2A  A0111105   A01111
# 1  8558         14        0      749       2        2A  A0111111   A01111
# 2  8558         14        0      749       2        2A  A0111111   A01111
# 3  8558         14        0      749       2        2A  A0111114   A01111
# 4  8558         14        0      749       2        2A  A0111201   A01112
#
#    clase grupo division  r_imputado  cantidad unmed   monto  forma_pago  \
# 0  A0111  A011      A01           2     1.732     K  186.19         1.0
# 1  A0111  A011      A01           2     4.330     K  173.20         1.0
# 2  A0111  A011      A01           2    10.825     K  433.00         1.0
# 3  A0111  A011      A01           2     2.165     K  151.55         1.0
# 4  A0111  A011      A01           2     2.165     K   73.61         1.0
#
#    tipo_negocio  modo_adq  lugar_adq
# 0           3.0       1.0        2.0
# ...
